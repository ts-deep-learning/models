# %%
import tensorflow as tf

# %%
detection_graph = tf.Graph()
with detection_graph.as_default():
    od_graph_def = tf.GraphDef()
    with tf.gfile.GFile('/home/dhivakar/work/projects/main/cotton_detection/tf_obj_det/research/object_detection/saved_models/P_051/frozen_inference_graph_P051_tf1-15-3.pb', 'rb') as fid:
        serialized_graph = fid.read()
        od_graph_def.ParseFromString(serialized_graph)
        tf.import_graph_def(od_graph_def, name='')

# %%
detection_graph.get_operations()
# Out:
# [<tf.Operation 'Const' type=Const>,
#  <tf.Operation 'image_tensor' type=Placeholder>,
#  <tf.Operation 'Cast' type=Cast>,
#  <tf.Operation 'Preprocessor/map/Shape' type=Shape>,
#  <tf.Operation 'Preprocessor/map/strided_slice/stack' type=Const>,
#  <tf.Operation 'Preprocessor/map/strided_slice/stack_1' type=Const>,
#  <tf.Operation 'Preprocessor/map/strided_slice/stack_2' type=Const>,
#  <tf.Operation 'Preprocessor/map/strided_slice' type=StridedSlice>,
#  <tf.Operation 'Preprocessor/map/TensorArray' type=TensorArrayV3>,
#  <tf.Operation 'Preprocessor/map/TensorArrayUnstack/Shape' type=Shape>,
#  <tf.Operation 'Preprocessor/map/TensorArrayUnstack/strided_slice/stack' type=Const>,
#  <tf.Operation 'Preprocessor/map/TensorArrayUnstack/strided_slice/stack_1' type=Const>,
#  <tf.Operation 'Preprocessor/map/TensorArrayUnstack/strided_slice/stack_2' type=Const>,
#  <tf.Operation 'Preprocessor/map/TensorArrayUnstack/strided_slice' type=StridedSlice>,
# ...

# %%
mixed5b = detection_graph.get_tensor_by_name('FeatureExtractor/InceptionV2/InceptionV2/Mixed_5b/concat:0')

# %%
tape = tf.GradientTape()

# %%
ops = detection_graph.get_operations()
all_tensor_names = {output.name for op in ops for output in op.outputs}

# %%
list(all_tensor_names)
# Out:
# ['FeatureExtractor/InceptionV2/Mixed_5c_2_Conv2d_3_3x3_s2_256/BatchNorm/gamma/read:0',
#  'MultipleGridAnchorGenerator/Meshgrid/ExpandedShape_1/Slice_1/size:0',
#  'FeatureExtractor/InceptionV2/Mixed_3b/Branch_2/Conv2d_0b_3x3/BatchNorm/moving_mean:0',
#  'FeatureExtractor/InceptionV2/InceptionV2/Mixed_4e/Branch_2/Conv2d_0b_3x3/Relu6:0',
#  'FeatureExtractor/InceptionV2/InceptionV2/Mixed_4c/concat:0',
#  'FeatureExtractor/InceptionV2/Mixed_5b/Branch_2/Conv2d_0a_1x1/BatchNorm/beta/read:0',
#  'FeatureExtractor/InceptionV2/InceptionV2/Mixed_3c/Branch_2/Conv2d_0a_1x1/BatchNorm/FusedBatchNormV3:1',
#  'Postprocessor/BatchMultiClassNonMaxSuppression/map/while/NextIteration_7:0',
#  'FeatureExtractor/InceptionV2/Mixed_4b/Branch_2/Conv2d_0c_3x3/BatchNorm/beta:0',
#  'FeatureExtractor/InceptionV2/InceptionV2/Mixed_3b/Branch_3/Conv2d_0b_1x1/BatchNorm/FusedBatchNormV3:2',
#  'MultipleGridAnchorGenerator/Meshgrid_10/Reshape:0',
# ...

# %%
mixed5b
# Out:
# <tf.Tensor 'FeatureExtractor/InceptionV2/InceptionV2/Mixed_5b/concat:0' shape=(?, ?, ?, 1024) dtype=float32>

# %%
mixed5b.
